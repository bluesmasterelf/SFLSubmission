# %%
# Imports
from random import random
from mido import MidiFile
import matplotlib.pyplot as plt

# %%
# Load data. 
mid = MidiFile('composerMidis/musicnet_midis/Beethoven/2318_bh38m1.mid', clip=True)

# %%
# Visualize some of the data

print(mid)
# Track zero appears to house primarily the track name and tempo data. 
for track in mid.tracks[1:3]:    
    notes = [note for note in track if note.type == 'note_on']
    pitch = [note.note for note in notes]
    plt.plot(*[pitch])
    plt.show()
# Out:
# <midi file 'composerMidis/musicnet_midis/Beethoven/2318_bh38m1.mid' type 1, 6 tracks, 15274 messages>
